# %%
import numpy as np

# %%
def convert_arr_np(array: list) -> np.array:
    return np.array(array)

# %% [markdown]
# Problem 1: Array basics
#
# Create np.array([2, 4, 6, 8, 10]); print it with 10 added to every element. Multiply [1, 2, 3] by [4, 5, 6] elementwise. Print the mean of the first array.

# %%
array = [2, 4, 6, 8, 10]

array_a = [1, 2, 3]
array_b = [4, 5, 6]

np_array = np.array(array)

print(f"plus 10: {np_array+10}")
print(f"product: {array_a*array_b}")
# Out:
# plus 10: [12 14 16 18 20]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5
#       6 np_array = np.array(array)
#       7
#       8 print(f"plus 10: {np_array+10}")
# ----> 9 print(f"product: {array_a*array_b}")
#
# TypeError: can't multiply sequence by non-int of type 'list'
